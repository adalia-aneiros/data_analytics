# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_05

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "Im Oberstadel 18, 8405 Winterthur",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
print(f"{base_url}{urllib.parse.urlencode(parameters)}")
# Out:
# https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText=Im+Oberstadel+18%2C+8405+Winterthur&origins=address&type=locations

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                              attrs
# featureId                                1156629_0
# label      Im Oberstadel 18 <b>8405 Winterthur</b>
# lat                                      47.480595
# lon                                       8.774889
# x                                     259727.21875
# y                                         700715.5

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[['web-scraper-order', 
                                    'address_raw', 
                                    'datetime',
                                    'rooms', 
                                    'area', 
                                    'luxurious',
                                    'price_per_m2']] # first 100 apartment adresses

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(10)
# Out:
# /workspaces/data_analytics/Week_05
# supermarkets_data_prepared.csv
# apartments_data_prepared.csv
# (865, 7)
#   web-scraper-order                             address_raw  \
# 0      1693998201-1       Neuhusstrasse 6, 8630 Rüti ZH, ZH
# 1      1693998201-2      Zürcherstrasse 1, 8173 Neerach, ZH
# 2      1693998201-4     Cramerstrasse 8-12, 8004 Zürich, ZH
# 3      1693998201-5       Rotachstrasse 33, 8003 Zürich, ZH
# 4     1693998201-16         Wolframplatz 1, 8045 Zürich, ZH
# 5     1693998205-25    Badenerstrasse 67, 8953 Dietikon, ZH
# 6     1693998205-26   Frowiesstrasse 36, 8344 Bäretswil, ZH
# 7     1693998205-27  Kanzleistrasse 15, 8418 Schlatt ZH, ZH
# 8     1693998205-29           Bolletweg 14, 8934 Knonau, ZH
# 9     1693998205-30            Im Zauner 24, 8352 Elsau, ZH
#
#               datetime  rooms   area  luxurious  price_per_m2
# 0  2023-09-06 15:10:34    3.0   49.0          0         29.41
# 1  2023-09-06 15:10:34    3.5   65.0          0         28.46
# 2  2023-09-06 15:10:34    2.0   54.0          0         89.87
# 3  2023-09-06 15:10:34    2.0   49.0          0         88.47
# 4  2023-09-06 15:10:34    2.0   32.0          0        109.84
# 5  2023-09-06 15:10:34    3.5  105.0          0         30.48
# 6  2023-09-06 15:10:34    5.5  140.0          0         19.64
# 7  2023-09-06 15:10:34    4.5  104.0          0         25.96
# 8  2023-09-06 15:10:34    5.5  150.0          0         22.60
# 9  2023-09-06 15:10:34    3.0   70.0          0         35.00

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address_raw'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address_raw']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address_raw'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                          address_raw             datetime  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH  2023-09-06 15:10:34
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH  2023-09-06 15:10:34
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH  2023-09-06 15:10:34
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH  2023-09-06 15:10:34
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH  2023-09-06 15:10:34
#
#    rooms  area  luxurious  price_per_m2        lat       lon
# 0    3.0  49.0          0         29.41  47.252167  8.845798
# 1    3.5  65.0          0         28.46  47.513332  8.474851
# 2    2.0  54.0          0         89.87        NaN       NaN
# 3    2.0  49.0          0         88.47  47.370792  8.514748
# 4    2.0  32.0          0        109.84  47.362282  8.522193

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address_raw']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_845f2cd6ad44ea44879a589750c63630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_845f2cd6ad44ea44879a589750c63630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_845f2cd6ad44ea44879a589750c63630 = L.map(
#                 &quot;map_845f2cd6ad44ea44879a589750c63630&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15ae7fba43258ba0397bee4ac2532fcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15ae7fba43258ba0397bee4ac2532fcf.addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#             var marker_cd456e125314c905dada2f3353ed30e1 = L.marker(
#                 [47.252166748046875, 8.845797538757324],
#                 {}
#             ).addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#         var popup_10a30931277b0981b200eed577ec07c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdea3c6104ca8276626103561cc9bb56 = $(`&lt;div id=&quot;html_bdea3c6104ca8276626103561cc9bb56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neuhusstrasse 6, 8630 Rüti ZH, ZH&lt;/div&gt;`)[0];
#                 popup_10a30931277b0981b200eed577ec07c4.setContent(html_bdea3c6104ca8276626103561cc9bb56);
#
#
#
#         marker_cd456e125314c905dada2f3353ed30e1.bindPopup(popup_10a30931277b0981b200eed577ec07c4)
#         ;
#
#
#
#
#             var marker_7b3ab7b8a464f23d9b0d71f6115d9bce = L.marker(
#                 [47.51333236694336, 8.47485065460205],
#                 {}
#             ).addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#         var popup_f7a134a568f6a0a679e09d03d158048d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7b7be0ce89584d8f57a848ee8914f5a = $(`&lt;div id=&quot;html_f7b7be0ce89584d8f57a848ee8914f5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zürcherstrasse 1, 8173 Neerach, ZH&lt;/div&gt;`)[0];
#                 popup_f7a134a568f6a0a679e09d03d158048d.setContent(html_f7b7be0ce89584d8f57a848ee8914f5a);
#
#
#
#         marker_7b3ab7b8a464f23d9b0d71f6115d9bce.bindPopup(popup_f7a134a568f6a0a679e09d03d158048d)
#         ;
#
#
#
#
#             var marker_10e0ba4f2ab02ada7795e07ae4c38360 = L.marker(
#                 [47.370792388916016, 8.514747619628906],
#                 {}
#             ).addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#         var popup_8fcabca4ffb5e4de0cebce208ea2829d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6adcf222c1f0d5df3900c6e1b73df39 = $(`&lt;div id=&quot;html_b6adcf222c1f0d5df3900c6e1b73df39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rotachstrasse 33, 8003 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_8fcabca4ffb5e4de0cebce208ea2829d.setContent(html_b6adcf222c1f0d5df3900c6e1b73df39);
#
#
#
#         marker_10e0ba4f2ab02ada7795e07ae4c38360.bindPopup(popup_8fcabca4ffb5e4de0cebce208ea2829d)
#         ;
#
#
#
#
#             var marker_14f07b3e0e63d421e57668d9fe63a4e4 = L.marker(
#                 [47.362281799316406, 8.52219295501709],
#                 {}
#             ).addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#         var popup_a451f3e11baef39d5b29daa403ad1675 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e65b4a0627e55cd34f006e8757ac97fb = $(`&lt;div id=&quot;html_e65b4a0627e55cd34f006e8757ac97fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wolframplatz 1, 8045 Zürich, ZH&lt;/div&gt;`)[0];
#                 popup_a451f3e11baef39d5b29daa403ad1675.setContent(html_e65b4a0627e55cd34f006e8757ac97fb);
#
#
#
#         marker_14f07b3e0e63d421e57668d9fe63a4e4.bindPopup(popup_a451f3e11baef39d5b29daa403ad1675)
#         ;
#
#
#
#
#             var marker_9ce2c3e97288470923823f40d23575ce = L.marker(
#                 [47.40792465209961, 8.392560958862305],
#                 {}
#             ).addTo(map_845f2cd6ad44ea44879a589750c63630);
#
#
#         var popup_bddf7e39ee2f0442ebc89a9150ce4599 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1beba6f8c2f53180df9c8fd94506fa26 = $(`&lt;div id=&quot;html_1beba6f8c2f53180df9c8fd94506fa26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badenerstrasse 67, 8953 Dietikon, ZH&lt;/div&gt;`)[0];
#                 popup_bddf7e39ee2f0442ebc89a9150ce4599.setContent(html_1beba6f8c2f53180df9c8fd94506fa26);
#
#
#
#         marker_9ce2c3e97288470923823f40d23575ce.bindPopup(popup_bddf7e39ee2f0442ebc89a9150ce4599)
#         ;

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('Geodata/apartments_data_geocoded_all.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-16 12:13:30
# Python Version: 3.11.10
# -----------------------------------
