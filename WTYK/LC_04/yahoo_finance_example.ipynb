# %% [markdown]
# # Stock market analysis using data from the Yahoo-Finance Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

# Install additional library yfinance
# !pip install yfinance
import yfinance as yf

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(os.getcwd())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-0.2.44-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=1.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (2024.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.5-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 34.2 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/vscode/.local/lib/python3.11/site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /home/vscode/.local/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.44-py2.py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 1.8 MB/s eta 0:00:00eta 0:00:01
# Downloading frozendict-2.4.5-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 3.1 MB/s eta 0:00:00
# Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 33.8 MB/s eta 0:00:00:00:01
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.6-cp311-cp311-linux_x86_64.whl size=898696 sha256=bcbdbe4488ac79676a3c233d64d3553f07eac96d6eb3124932fcb90ac806c665
#   Stored in directory: /home/vscode/.cache/pip/wheels/1c/09/7e/9f659fde248ecdc1722a142c1d744271aad3914a0afc191058
# Successfully built peewee
# Installing collected packages: peewee, multitasking, lxml, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.5 html5lib-1.1 lxml-5.3.0 multitasking-0.0.11 peewee-3.17.6 yfinance-0.2.44
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# /workspaces/data_analytics/WTYK/LC_04

# %% [markdown]
# ## 1.) Get data for the stock TSLA (Tesla) from Yahoo Finance

# %%
# Get current date from datetime in the format YYYY-MM-DD
today = datetime.today().strftime('%Y-%m-%d')

# Retrieve the TESLA stock data from Yahoo finance using yf.download
df = yf.download('TSLA', start='2020-01-01', end=today)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %% [markdown]
# ## 2.) Apply non-graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) What are the values for min, max. mean and median of the close price?

# %%
# Describe the dataframe
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1198.000000  1198.000000  1198.000000  1198.000000  1198.000000
# mean    207.816478   212.477648   202.851071   207.764899   207.764899
# std      79.703253    81.290256    77.825242    79.526874    79.526874
# min      24.980000    26.990667    23.367332    24.081333    24.081333
# 25%     171.742496   175.087502   167.445000   171.767494   171.767494
# 50%     217.821671   222.250000   212.279999   217.606667   217.606667
# 75%     255.309998   260.262505   250.442505   255.852497   255.852497
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.198000e+03
# mean   1.271780e+08
# std    8.328369e+07
# min    2.940180e+07
# 25%    7.637445e+07
# 50%    1.031929e+08
# 75%    1.469126e+08
# max    9.140820e+08

# %% [markdown]
# ### b) What is the 10% Quantile and 90% quantile of close price?

# %%
# Calculate quantiles for the dataframe (10% and 90%)
df.quantile([0.1, 0.9])
# Out:
#            Open        High         Low       Close   Adj Close       Volume
# 0.1   66.641932   67.669530   65.852335   66.767733   66.767733   59849160.0
# 0.9  299.995343  306.049997  291.648007  299.769998  299.769998  224414700.0

# %% [markdown]
# ## 3.) Apply graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) Create a line chart of the close price

# %%
# Create a line chart of the close price
plt.plot(df['Close'])

# Set the title and axis labels
plt.title('Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')

# Add a legend to the axis
plt.legend(['Close'])

# Add grid
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# ### b) Create a histogram of the close price

# %%
# Create a histogram of the close price
plt.hist(df['Close'], bins=20)

# Plot settings
plt.title('Tesla Stock Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# ### c) Create a boxplot of the close price

# %%
# Create a boxplot of the close price
plt.boxplot(df['Close'])
plt.title('Tesla Stock Price')
plt.ylabel('Price')
plt.xlabel('Close')


# Show the plot
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-07 15:33:11
# Python Version: 3.11.10
# -----------------------------------
